# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %%
plt.style.use('ggplot')
# pd.set_option('max_columns', 2)
pd.set_option('display.max_columns', 200)

file_path = 'assets/data.xlsx'
df = pd.read_excel(file_path, header=[2,3])
# df.columns = df.columns.get_level_values(1)

# %%
# df.columns = df.columns.get_level_values(1)
# df.columns

# %%
# culture_interest_columns
df

interest_columns = ['Q1.3.1',
 'Q1.3.2',
 'Q1.3.3',
 'Q1.3.4',
 'Q1.3.5',
 'Q1.3.6',
 'Q1.3.7',
 'Q1.3.8',
 'Q1.3.9',
 'Q1.3.10',
 'Q1.3.11',
 'Q1.3.12',
 'Q1.3.13',
 'Q1.3.14'
]

culture_interest_columns = df.loc[:, (slice(None), interest_columns)].copy()
culture_interest_columns

# %%
print(culture_interest_columns)
# average_interest_levels = culture_interest_columns.mean().copy()
# average_interest_levels

# %%
df.head()
# Out:
#             Response Id          Date  \
# 0                   NaN           NaN
# 1            responseId          DATE
# 2  TOCfzxpJdjG0AfXJpIuc  Dec 23, 2023
# 3  asChH1Fz7zSLLMJtzotu  Dec 23, 2023
# 4  qhCCVWPSQw3U6Zr6UyMe  Dec 23, 2023
#
#   Do you work for any of the following types of business or profession?  \
# 0                                                NaN
# 1                                                 S1
# 2                                                  9
# 3                                                  9
# 4                                                  9
#
#   Please indicate your nationality.   \
# 0                             1 to 3
# 1                                 S2
# 2                                  1
# 3                                  1
# 4                                  1
#
#   Please indicate your nationality. _comment  \
# 0                                        NaN
# 1                                 S2-Comment
# ...

# %%
# df = pd.DataFrame(newdf)

# Save the DataFrame to an Excel file
newdf.to_excel('sample_discorvery.xlsx', index=False)

print("Sample Excel file created: sample_data.xlsx")
# Out:
# Sample Excel file created: sample_data.xlsx

# %%
from pprint import pprint
pprint(df.columns.tolist())
# Out:
# ['Response Id',
#  'Date',
#  'Do you work for any of the following types of business or profession?',
#  'Please indicate your nationality. ',
#  'Please indicate your nationality. _comment',
#  'Please indicate your residence status. ',
#  'Can you please let me know your age? ',
#  'What is your gender?',
#  'Which region of Saudi Arabia do you reside at?',
#  'Which city do you live at?',
#  'Which city do you live at?_comment',
#  'In general, which of the following cultural activities could people do in '
#  'Saudi Arabia, on the scale of 1 to 7 where 1 is Not possible at all and 7 is '
#  'Always possible?_Watching movies in the cinema ',
#  'In general, which of the following cultural activities could people do in '
#  'Saudi Arabia, on the scale of 1 to 7 where 1 is Not possible at all and 7 is '
#  'Always possible?_Visiting book fairs',
#  'In general, which of the following cultural activities could people do in '
# ...

# %%
df.columns.get_level_values(0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.columns.get_level_values(1)
#
# File ~/Documents/ryugoku/saudi_analysis/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:2077, in Index._get_level_values(self, level)
#    2041 def _get_level_values(self, level) -> Index:
#    2042     """
#    2043     Return an Index of values for requested level.
#    2044
#    (...)
#    2075     Index(['a', 'b', 'c'], dtype='object')
#    2076     """
# -> 2077     self._validate_index_level(level)
#    2078     return self
#
# File ~/Documents/ryugoku/saudi_analysis/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:1983, in Index._validate_index_level(self, level)
#    1978         raise IndexError(
#    1979             "Too many levels: Index has only 1 level, "
#    1980             f"{level} is not a valid level number"
# ...

# %%
df.describe
